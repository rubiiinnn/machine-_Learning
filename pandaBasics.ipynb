# %% [markdown]
# <a href="https://colab.research.google.com/github/rubiiinnn/machine-_Learning/blob/main/pandaBasics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
#Dataset load krna

# %%
#file upload krne ka tareeqa
from google.colab import files

files.upload()
# Out:
#      <input type="file" id="files-808f2d1b-4d6d-4372-ae6d-6d1574601469" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-808f2d1b-4d6d-4372-ae6d-6d1574601469">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("Iris.csv") #df = datframe like a table

# %%
#CHECK YOUR DATA SBSE PEHLE

# %%
df.head()     #first 5 rows
df.shape      # Rows, Columns
df.info()     # Data type + missing values
df.describe() # Math summary
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# ...

# %%
#check for missing values - ye bhi important step hai
# agr missing value hai to model ache se kam nai krta - error deta hai

# %%
df.isnull().sum()  #humare dataset mai koi missing value nai hai
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
#if there is missing value
# 1) missing data vali rows ko dlt krdo - df.dropna(inplace=True) - kam dataset ke liye hi sahi hai bs ,ML ki accuracy gir skti

#2)0 se fill krdo - df.fillna(0, inplace=True) - can give glt result

#3) Mean se fill krna - df["Age"].mean() - mean calculate kro
#                       df["Age"].fillna(df["Age"].mean(), inplace=True) - fill krdo
#                       df["Age"].fillna(df["Age"].mean(), inplace=True)

#4) MODE (text data ke liye) - zyada occurence vo data fill in the missing places
#                             df["City"].fillna(df["City"].mode()[0], inplace=True)

# %%
#ENCODING - Text data ko number mai
# Speciies - oobject hai - inhe number mai kro

# %%
df = pd.get_dummies(df, drop_first=True)

# %%
#Dlt useless column - id use ki nai usko htaa do

# %%
df.drop("Id", axis=1, inplace=True)

# %%
#INPUT (x) & OUTPUT (y)
# hum species predict krna chate hai - output
#  df.iloc[ rows , columns ] - jab Tumhara target column last me ho use this

# %%
X = df.iloc[:, :-1] #Saari rows ,  Last column ko chhod ke baaki sab columns
y = df.iloc[:, -1]

# %%
#check final data

# %%
print(X.shape)
print(y.shape)
# Out:
# (150, 5)
# (150,)
